# %%
from sklearn.cluster import KMeans as KM
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler as SS
from sklearn.manifold import TSNE
from sklearn.model_selection import GridSearchCV as GSCV
from sklearn.model_selection import train_test_split as TTS
import pandas as pd
from sklearn.decomposition import PCA

# %%
#reading in CSV and viewing
df = pd.read_csv('crypto_data.csv')

#making df into Pandas DataFrame
df = pd.DataFrame(df)

#print to check
df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1247     1.283270e+05         1000000
# 1248     2.149121e+07       100000000
# 1249              NaN       233100000
# 1250              NaN        21000000
# 1251              NaN        40000000
#
# [1252 rows x 7 columns]

# %%
#drop all rows that have value FALSE in IsTrading column

df = df[df.IsTrading != False]

df
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1243              NaN      1000000000
# 1244              NaN      1000000000
# 1245     9.802226e+08      1400222610
# 1246     7.296538e+06        21000000
# 1247     1.283270e+05         1000000
#
# [1144 rows x 7 columns]

# %%
#drop column IsTrading

df = df.drop('IsTrading',1)

df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin          X11   PoW/PoS              NaN
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven      SHA-256       PoW              NaN
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...          ...       ...              ...
# 1243       SERO   Super Zero       Ethash       PoW              NaN
# 1244        UOS          UOS      SHA-256      DPoI              NaN
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...              ...
# 1243      1000000000
# 1244      1000000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
#
# [1144 rows x 6 columns]

# %%
#drop all rows that have NA 

df = df.dropna()

df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...              ...
# 1238      2000000000
# 1242       250000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
#
# [685 rows x 6 columns]

# %%
#dropping crypto that has not been mined (TotalCoinsMined > 0)
df = df[df.TotalCoinsMined > 0]

df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8           ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...              ...
# 1238      2000000000
# 1242       250000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
#
# [532 rows x 6 columns]

# %%
#creating coin_name df 

coin_name = df['CoinName']
coin_name
# Out:
# 0           42 Coin
# 2           404Coin
# 5         EliteCoin
# 7           Bitcoin
# 8          Ethereum
#            ...
# 1238         ZEPHYR
# 1242        Gapcoin
# 1245         Beldex
# 1246        Horizen
# 1247    BitcoinPlus
# Name: CoinName, Length: 532, dtype: object

# %%
#dropping CoinName and Unnamed: 0

df = df.drop('CoinName', 1)
df = df.drop('Unnamed: 0', 1)

df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
#getting Dummy variables for Algorithm and ProofType columns
df = pd.get_dummies(df)

df
# Out:
#       TotalCoinsMined  Algorithm_1GB AES Pattern Search  Algorithm_536  \
# 0        4.199995e+01                                 0              0
# 2        1.055185e+09                                 0              0
# 5        2.927942e+10                                 0              0
# 7        1.792718e+07                                 0              0
# 8        1.076842e+08                                 0              0
# ...               ...                               ...            ...
# 1238     2.000000e+09                                 0              0
# 1242     1.493105e+07                                 0              0
# 1245     9.802226e+08                                 0              0
# 1246     7.296538e+06                                 0              0
# 1247     1.283270e+05                                 0              0
#
#       Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0                     0                   0                0
# 2                     0                   0                0
# 5                     0                   0                0
# 7                     0                   0                0
# 8                     0                   0                0
# ...                 ...                 ...              ...
# 1238                  0                   0                0
# 1242                  0                   0                0
# 1245                  0                   0                0
# 1246                  0                   0                0
# 1247                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  \
# 0                     0                  0              0
# 2                     0                  0              0
# 5                     0                  0              0
# 7                     0                  0              0
# 8                     0                  0              0
# ...                 ...                ...            ...
# 1238                  0                  0              0
# 1242                  0                  0              0
# 1245                  0                  0              0
# 1246                  0                  0              0
# 1247                  0                  0              0
#
#       Algorithm_Cloverhash  ...  TotalCoinSupply_91388946  \
# 0                        0  ...                         0
# 2                        0  ...                         0
# 5                        0  ...                         0
# 7                        0  ...                         0
# 8                        0  ...                         0
# ...                    ...  ...                       ...
# 1238                     0  ...                         0
# 1242                     0  ...                         0
# 1245                     0  ...                         0
# 1246                     0  ...                         0
# 1247                     0  ...                         0
#
#       TotalCoinSupply_92000000000  TotalCoinSupply_9354000  \
# 0                               0                        0
# 2                               0                        0
# 5                               0                        0
# 7                               0                        0
# 8                               0                        0
# ...                           ...                      ...
# 1238                            0                        0
# 1242                            0                        0
# 1245                            0                        0
# 1246                            0                        0
# 1247                            0                        0
#
#       TotalCoinSupply_9507271  TotalCoinSupply_9736000  \
# 0                           0                        0
# 2                           0                        0
# 5                           0                        0
# 7                           0                        0
# 8                           0                        0
# ...                       ...                      ...
# 1238                        0                        0
# 1242                        0                        0
# 1245                        0                        0
# 1246                        0                        0
# 1247                        0                        0
#
#       TotalCoinSupply_98000000  TotalCoinSupply_98100000000  \
# 0                            0                            0
# 2                            0                            0
# 5                            0                            0
# 7                            0                            0
# 8                            0                            0
# ...                        ...                          ...
# 1238                         0                            0
# 1242                         0                            0
# 1245                         0                            0
# 1246                         0                            0
# 1247                         0                            0
#
#       TotalCoinSupply_990000000000  TotalCoinSupply_999481516  \
# 0                                0                          0
# 2                                0                          0
# 5                                0                          0
# 7                                0                          0
# 8                                0                          0
# ...                            ...                        ...
# 1238                             0                          0
# 1242                             0                          0
# 1245                             0                          0
# 1246                             0                          0
# 1247                             0                          0
#
#       TotalCoinSupply_9999999
# 0                           0
# 2                           0
# 5                           0
# 7                           0
# 8                           0
# ...                       ...
# 1238                        0
# 1242                        0
# 1245                        0
# 1246                        0
# 1247                        0
#
# [532 rows x 377 columns]

# %%
#scale data to standardize 

scaler = SS()

scaler.fit(df)

df_scaled = scaler.transform(df)

# %%
# performing dimensionality reduction with PCA

pca = PCA(n_components = .90)
df_pca = pca.fit_transform(df_scaled)

df_pca.shape
# Out:
# (532, 274)

# %%
#creating new dataframe for tsne

df_tsne = pd.DataFrame(df_pca)

df_tsne.head()
# Out:
#         0         1             2             3         4         5    \
# 0 -0.267092 -0.116294 -2.757328e-15  2.186894e-15  0.029497  1.514572
# 1 -0.249925 -0.117273 -3.250167e-15  1.058796e-15  0.025167  1.513565
# 2  0.314746 -0.002862  2.447137e-16  2.009568e-15 -0.081839  2.496209
# 3 -0.250886 -0.222136  5.905327e-15  1.477623e-17  0.000999 -1.566613
# 4 -0.119293 -0.222472  2.250542e-15  1.656100e-15 -0.042473 -1.511262
#
#         6         7         8         9    ...           264           265  \
# 0 -0.340449  0.089601 -1.867751 -0.424150  ...  3.171457e-01 -8.361316e-01
# 1 -0.340359  0.089820 -1.869831 -0.424478  ...  1.181194e+00  3.964897e-01
# 2 -0.409761 -0.375692 -1.377915  0.000210  ... -6.648966e-01  2.576352e+00
# 3  0.156332 -0.120727  0.360156  0.209244  ... -2.251520e-15 -3.961123e-16
# 4  0.136779 -0.073247  0.419963  0.077902  ...  7.947277e-16  2.282809e-15
#
#             266           267           268           269           270  \
# 0  2.502189e-01 -7.177191e-01  1.519058e+00 -9.226036e-01  7.548178e-01
# 1  2.636099e+00 -9.936792e-01 -6.661969e-01 -4.202546e-01 -8.495283e-01
# 2 -1.033072e+00  9.565872e-02  1.041433e+00  6.092059e-01 -4.858294e-02
# 3 -1.058803e-15  1.335393e-15  1.001232e-16  2.019359e-15  4.078768e-15
# 4  1.551909e-15  4.205174e-16  2.503080e-16 -5.534739e-16 -2.941118e-16
#
#             271           272           273
# 0  1.251521e+00  6.828822e-01 -1.509471e+00
# 1 -6.730102e-01 -1.973161e+00  1.702251e+00
# 2  1.138371e+00  1.676535e+00 -2.715599e+00
# 3  9.136240e-16 -2.490564e-16  1.838512e-15
# 4 -1.727125e-15  1.193969e-15  1.802217e-16
#
# [5 rows x 274 columns]

# %%
#Initialize tsne model

tsne = TSNE(learning_rate = 35)

# %%
# Using tSNE to reduce the data set dimensions 

df_tsne = tsne.fit_transform(df_tsne)

#Checking Shape 

df_tsne.shape
# Out:
# (532, 2)

# %%
#Preparing the Plot Data Set

x = df_tsne[:,0]
y = df_tsne[:,1]

#putting Variables into data set 
df_tsne = pd.DataFrame(df_tsne)

df_tsne["x"] = x
df_tsne['y'] = y

# %%
#Visualize the plot 

plt.scatter(df_tsne['x'], df_tsne['y'])
plt.show()

# %%
#Find best value for k for loop

inertia = []

k=list(range(1,11))

for i in k:
    km = KM(n_clusters=i, random_state=0)
    km.fit(df_tsne)
    inertia.append(km.inertia_)
# Out:
# C:\Users\Steph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
#Find best value for k elbow curve 

#dreating dataframe for plot
elbow_data = {"k":k, "inertia":inertia}
df_elbow = pd.DataFrame(elbow_data)

#Plot

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of Clusters')
plt.ylabel("Inertia")
plt.show()

# %%
#Based on this Data we will be able to cluster the cryptocurrencies together. 
#the recommended number of clusters to use would be three based on the elbow plot above.
